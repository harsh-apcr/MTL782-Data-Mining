# %% [markdown]
# # Data Pre-Proccesing

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import sys
sys.path.append('../../model_evaluation')

path = '../../codon-usage-data-set/'
df = pd.read_csv(path + 'codon_usage.csv', low_memory = False)

df = df[df.Kingdom != 'plm']

df = df[pd.to_numeric(df['UUU'], errors='coerce').notnull()]
df = df[pd.to_numeric(df['UUC'], errors='coerce').notnull()]

df.UUU = df.UUU.astype('float64')
df.UUC = df.UUC.astype('float64')

df.Kingdom = df.Kingdom.astype('category')
df.DNAtype = df.DNAtype.astype('category')

df = df[df.Ncodons > 1000]

df['Kingdom'] = df['Kingdom'].replace(
                      {'pln' : 'euk' ,
                       'inv' : 'euk' ,
                       'vrt' : 'euk' ,
                       'mam' : 'euk' ,
                       'rod' : 'euk' ,
                       'pri' : 'euk' 
                      })

df = df.reset_index(drop=True)
df.groupby('Kingdom').size()
# Out:
# Kingdom
# arc     126
# bct    2918
# phg     220
# euk    6903
# vrl    2831
# dtype: int64

# %%
# Tuning the hyper-parameter (max_leaf_nodes of the decision_tree_classifier)
from dt_training import tree_training
from KFold import KFold

class_vars = pd.Series(['arc', 'bct', 'phg', 'euk', 'vrl'], dtype='category')
codon_columns = [c for c in df.columns if c not in ['Kingdom', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName']]

kfold = KFold(5, shuffle = True, random_state = 1)
print('Iteration Starts')
for i in range(2,20):
    tot_train = 0
    tot_test = 0
    for idx_train, idx_test in kfold.split(df):
        X_train = df.loc[idx_train, codon_columns]
        y_train = df.loc[idx_train, 'Kingdom']

        X_test = df.loc[idx_test, codon_columns]
        y_test = df.loc[idx_test, 'Kingdom']

        train, test = tree_training(i, class_vars, X_train, y_train, X_test, y_test)
        tot_train += train
        tot_test += test
    
    # print the average training accuracy for model with max_leaf_nodes = i
    print(f'max_leaf_nodes:{i} ,training-accuracy:{round(tot_train / 5, 3)}, test-accuracy:{round(tot_test / 5, 3)}')
print('Iteration Ends\n----------------------------')
# Out:
# Iteration Starts
# max_leaf_nodes:2 ,training-accuracy:0.244, test-accuracy:0.238
# max_leaf_nodes:3 ,training-accuracy:0.422, test-accuracy:0.416
# max_leaf_nodes:4 ,training-accuracy:0.556, test-accuracy:0.552
# max_leaf_nodes:5 ,training-accuracy:0.542, test-accuracy:0.537
# max_leaf_nodes:6 ,training-accuracy:0.565, test-accuracy:0.56
# max_leaf_nodes:7 ,training-accuracy:0.565, test-accuracy:0.56
# max_leaf_nodes:8 ,training-accuracy:0.574, test-accuracy:0.572
# max_leaf_nodes:9 ,training-accuracy:0.584, test-accuracy:0.582
# max_leaf_nodes:10 ,training-accuracy:0.607, test-accuracy:0.604
# max_leaf_nodes:11 ,training-accuracy:0.617, test-accuracy:0.613
# max_leaf_nodes:12 ,training-accuracy:0.61, test-accuracy:0.606
# max_leaf_nodes:13 ,training-accuracy:0.589, test-accuracy:0.578
# max_leaf_nodes:14 ,training-accuracy:0.592, test-accuracy:0.584
# max_leaf_nodes:15 ,training-accuracy:0.626, test-accuracy:0.618
# max_leaf_nodes:16 ,training-accuracy:0.634, test-accuracy:0.626
# max_leaf_nodes:17 ,training-accuracy:0.637, test-accuracy:0.629
# max_leaf_nodes:18 ,training-accuracy:0.634, test-accuracy:0.626
# max_leaf_nodes:19 ,training-accuracy:0.634, test-accuracy:0.624
# Iteration Ends
# ----------------------------

# %% [markdown]
# We can clearly observe from above outcomes , best performance on validation set (with minimum number of leaf nodes) is for 11 nodes
#
# `max_leaf_nodes:11 ,training-accuracy:0.617, test-accuracy:0.613`
#
# Now, we'll create our final model using `max_leaf_nodes = 11`

# %%
model_tree = DecisionTreeClassifier(max_leaf_nodes = 11, class_weight = 'balanced')
X = df.loc[:,codon_columns]
y = df['Kingdom']
model_tree.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_leaf_nodes=11)

# %%
from sklearn.metrics import roc_curve, roc_auc_score

n = len(y)
m = len(class_vars)

# Predict class probabilities
y_pred = model_tree.predict(X)
dt_probs = model_tree.predict_proba(X)

plt.figure(figsize = (8, 8))
plt.title('ROC Plot (Decision Trees)')

plt.xlabel('FPR(False Positive Rate)')
plt.ylabel('TPR(True Positive Rate)')

_y = np.ones((n,),dtype="int8")
first = True
for i in range(m):
    if not first:
        _y = np.ones((n,),dtype="int8")
    
    class_name = class_vars[i]
    for j in range(n):
        if y[j] != class_name:
            _y[j] = 0
    dt_fpr, dt_tpr, _ = roc_curve(_y, dt_probs[:, i])
    plt.plot(dt_fpr, dt_tpr, marker='.', label= class_name)
    first = False

random_fpr, random_tpr, _ = roc_curve(_y, np.zeros((n,), dtype='int8'))
plt.plot(random_fpr, random_tpr, linestyle='--', label='Random prediction')

plt.legend()
plt.show()

# %% [markdown]
# As we can see for 'euk' (Eukaryotes) and 'phg' (Bacteriophage) , Decision Tree Model Doesn't work well

# %%
# Statistical Measures
import eval_metrics

conf_matrix = eval_metrics.confusion_matrix(y, y_pred, class_vars)
print('Accuracy:%.4f' %eval_metrics.accuracy(conf_matrix))
print('Precision:%.4f' %eval_metrics.precision(conf_matrix, class_vars))
print('Recall:%.4f' %eval_metrics.recall(conf_matrix, class_vars))
# Out:
# Accuracy:0.6411
# Precision:0.6411
# Recall:0.6411
