# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../../codon-usage-data-set/codon_usage.csv', low_memory = False)


df = df.drop(['SpeciesName', 'SpeciesID', 'DNAtype'], axis = 'columns')
df = df[pd.to_numeric(df['UUU'], errors='coerce').notnull()]
df = df[pd.to_numeric(df['UUC'], errors='coerce').notnull()]

df.UUU = df.UUU.astype('float64')
df.UUC = df.UUC.astype('float64')

df.Kingdom = df.Kingdom.astype('category')

df = df[df.Ncodons > 1000]

df['Kingdom'] = df['Kingdom'].replace(
                      {'pln' : 'euk' ,
                       'inv' : 'euk' ,
                       'vrt' : 'euk' ,
                       'mam' : 'euk' ,
                       'rod' : 'euk' ,
                       'pri' : 'euk' 
                      })

df = df[df.Kingdom != 'plm']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12998 entries, 0 to 13027
# Data columns (total 66 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Kingdom  12998 non-null  category
#  1   Ncodons  12998 non-null  int64
#  2   UUU      12998 non-null  float64
#  3   UUC      12998 non-null  float64
#  4   UUA      12998 non-null  float64
#  5   UUG      12998 non-null  float64
#  6   CUU      12998 non-null  float64
#  7   CUC      12998 non-null  float64
#  8   CUA      12998 non-null  float64
#  9   CUG      12998 non-null  float64
#  10  AUU      12998 non-null  float64
#  11  AUC      12998 non-null  float64
#  12  AUA      12998 non-null  float64
#  13  AUG      12998 non-null  float64
#  14  GUU      12998 non-null  float64
#  15  GUC      12998 non-null  float64
#  16  GUA      12998 non-null  float64
#  17  GUG      12998 non-null  float64
#  18  GCU      12998 non-null  float64
#  19  GCC      12998 non-null  float64
#  20  GCA      12998 non-null  float64
#  21  GCG      12998 non-null  float64
#  22  CCU      12998 non-null  float64
#  23  CCC      12998 non-null  float64
#  24  CCA      12998 non-null  float64
#  25  CCG      12998 non-null  float64
#  26  UGG      12998 non-null  float64
#  27  GGU      12998 non-null  float64
#  28  GGC      12998 non-null  float64
#  29  GGA      12998 non-null  float64
#  30  GGG      12998 non-null  float64
#  31  UCU      12998 non-null  float64
#  32  UCC      12998 non-null  float64
#  33  UCA      12998 non-null  float64
#  34  UCG      12998 non-null  float64
#  35  AGU      12998 non-null  float64
#  36  AGC      12998 non-null  float64
#  37  ACU      12998 non-null  float64
#  38  ACC      12998 non-null  float64
#  39  ACA      12998 non-null  float64
#  40  ACG      12998 non-null  float64
#  41  UAU      12998 non-null  float64
#  42  UAC      12998 non-null  float64
#  43  CAA      12998 non-null  float64
#  44  CAG      12998 non-null  float64
#  45  AAU      12998 non-null  float64
#  46  AAC      12998 non-null  float64
#  47  UGU      12998 non-null  float64
#  48  UGC      12998 non-null  float64
#  49  CAU      12998 non-null  float64
#  50  CAC      12998 non-null  float64
#  51  AAA      12998 non-null  float64
#  52  AAG      12998 non-null  float64
#  53  CGU      12998 non-null  float64
#  54  CGC      12998 non-null  float64
#  55  CGA      12998 non-null  float64
#  56  CGG      12998 non-null  float64
#  57  AGA      12998 non-null  float64
#  58  AGG      12998 non-null  float64
#  59  GAU      12998 non-null  float64
#  60  GAC      12998 non-null  float64
#  61  GAA      12998 non-null  float64
#  62  GAG      12998 non-null  float64
#  63  UAA      12998 non-null  float64
#  64  UAG      12998 non-null  float64
#  65  UGA      12998 non-null  float64
# dtypes: category(1), float64(64), int64(1)
# memory usage: 6.6 MB
